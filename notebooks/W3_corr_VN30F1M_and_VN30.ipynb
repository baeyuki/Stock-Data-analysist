# %% [markdown]
# # Caculate correlations between VN30F1M with VN30

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.simplefilter(action='ignore', category=FutureWarning) # Ignore all future warning

pd.set_option('display.width', 200)  # Increase total display width
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_rows', None)  # Show all rows

# %%
import sys
import os

# Get the absolute path of the `src` folder
src_path = os.path.abspath(os.path.join(os.getcwd(), "..", "src"))

# Add `src` to the system path
sys.path.insert(0, src_path)

from get_company_names.get_VN30_company_names import get_VN30_company_names

# %%
df = pd.read_csv('../data/processed/processed_sample_data.csv')
df.head()
# Out:
#    DTYYYYMMDD Ticker     Open     High      Low    Close    Volume  Outlier
# 0  2016-11-25    AAA  16.4270  16.4270  15.7932  15.7941  594710.0    False
# 1  2016-11-28    AAA  15.7932  15.8460  15.2122  15.5300  172720.0    False
# 2  2016-11-29    AAA  15.4763  15.5819  15.3178  15.5300  184960.0    False
# 3  2016-11-30    AAA  15.5291  15.5819  15.3178  15.5300  270300.0    False
# 4  2016-12-01    AAA  15.5819  15.6347  14.8952  14.8961  340430.0    False

# %%
import sys
import os

# Get the absolute path of the `src` folder
src_path = os.path.abspath(os.path.join(os.getcwd(), "..", "src"))

# Add `src` to the system path
sys.path.insert(0, src_path)

from compute_correlation.get_return_rates import get_return_rates
from compute_correlation.compute_correlation import compute_correlation

# %%
# Add some returns features for VNINDEX
VN30F1M_first_df = get_return_rates(pd.read_csv('../data/processed/processed_VN30F1M_data.csv'),'HNX:VN301!')
VN30F1M_first_df.head()
# Out:
#    DTYYYYMMDD      Ticker   Open   High    Low  Close  Volume  Outlier  daily_returns  weekly_returns  monthly_returns
# 0  2017-08-10  HNX:VN301!  757.9  757.9  745.5  745.9   367.0    False      -0.000268       -0.005497         0.055369
# 1  2017-08-11  HNX:VN301!  746.0  746.4  743.4  745.7   510.0    False      -0.000268       -0.005497         0.055369
# 2  2017-08-14  HNX:VN301!  745.9  748.9  745.7  748.9   707.0    False       0.004291       -0.005497         0.055369
# 3  2017-08-15  HNX:VN301!  750.3  750.9  748.0  748.0   946.0    False      -0.001202       -0.005497         0.055369
# 4  2017-08-16  HNX:VN301!  747.7  748.4  745.1  748.1  1065.0    False       0.000134       -0.005497         0.055369

# %%
# Caculate corralation between VNINDEX and VN100
companys = get_VN30_company_names()
for company in companys:
    company_df = get_return_rates(df,company)
    if not company_df.empty :
        print(f'Correlation indexs between VN30F1M and {company} are:')
        compute_correlation(VN30F1M_first_df,company_df,'daily_returns,weekly_returns,monthly_returns')
        print('\n')
# Out:
# Correlation indexs between VN30F1M and ACB are:
# Correlation of daily_returns between df1 and df2 is 0.7354206186951855
# Correlation of weekly_returns between df1 and df2 is 0.75133368883222
# Correlation of monthly_returns between df1 and df2 is 0.6750162112923199
#
#
# Correlation indexs between VN30F1M and BCM are:
# Correlation of daily_returns between df1 and df2 is 0.4062336385631196
# Correlation of weekly_returns between df1 and df2 is 0.3608609282339777
# Correlation of monthly_returns between df1 and df2 is 0.3807292920369151
#
#
# Correlation indexs between VN30F1M and BID are:
# Correlation of daily_returns between df1 and df2 is 0.6564746350878983
# Correlation of weekly_returns between df1 and df2 is 0.6593320159903593
# Correlation of monthly_returns between df1 and df2 is 0.5943194693259486
#
#
# Correlation indexs between VN30F1M and BVH are:
# Correlation of daily_returns between df1 and df2 is 0.5515739502756463
# ...
