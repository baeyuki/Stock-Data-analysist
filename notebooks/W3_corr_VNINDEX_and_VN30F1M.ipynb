# %% [markdown]
# # Caculate correlations between VNINDEX and VN30F1M

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings .simplefilter(action='ignore',category=FutureWarning) # Ignore all future warnings

pd.set_option('display.width', 200)  # Increase total display width
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_rows', None)  # Show all rows

# %%
import sys
import os

# Get the absolute path of the `src` folder
src_path = os.path.abspath(os.path.join(os.getcwd(), "..", "src"))

# Add `src` to the system path
sys.path.insert(0, src_path)

from compute_correlation.get_return_rates import get_return_rates
from compute_correlation.compute_correlation import compute_correlation

# %%
# Load data

df = pd.read_csv('../data/processed/processed_sample_data.csv')
VNINDEX_df = get_return_rates(df,'VNINDEX')

VN30F1M_first_df = pd.read_csv('../data/processed/processed_VN30F1M_data.csv')
VN30F1M_df = get_return_rates(VN30F1M_first_df,'HNX:VN301!')

# %%
# Caculate correlations
print('Correlation indexs between VNINDEX and VN30F1M are:')
compute_correlation(VNINDEX_df,VN30F1M_df,'daily_returns,weekly_returns,monthly_returns')
# Out:
# Correlation indexs between VNINDEX and VN30F1M are:
# Correlation of daily_returns between df1 and df2 is 0.8809922339337477
# Correlation of weekly_returns between df1 and df2 is 0.940513541861963
# Correlation of monthly_returns between df1 and df2 is 0.9589257703122684
#                  monthly_returns  monthly_returns  weekly_returns  weekly_returns  daily_returns  daily_returns
# monthly_returns         1.000000         0.958926        0.486774        0.471666       0.184682       0.159661
# monthly_returns         0.958926         1.000000        0.467653        0.495313       0.189903       0.190679
# weekly_returns          0.486774         0.467653        1.000000        0.940514       0.398486       0.333642
# weekly_returns          0.471666         0.495313        0.940514        1.000000       0.383213       0.376995
# daily_returns           0.184682         0.189903        0.398486        0.383213       1.000000       0.880992
# ...

# %%
from visualization.visualize_2_tickers import visualize_2_tickers

visualize_2_tickers(VNINDEX_df,VN30F1M_df,'VNINDEX','VN30F1M')
